# %%
# !pip install langchain  "pyautogen[retrievechat]"  PyPDF2  faiss-cpu
# Out:
# Requirement already satisfied: langchain in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (0.2.14)
# Collecting PyPDF2
#   Using cached pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.8.0.post1-cp310-cp310-win_amd64.whl.metadata (3.8 kB)
# Collecting pyautogen[retrievechat]
#   Downloading pyautogen-0.2.35-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: PyYAML>=5.3 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from langchain) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from langchain) (3.10.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.32 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from langchain) (0.2.32)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from langchain) (0.1.99)
# Requirement already satisfied: numpy<2,>=1 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from langchain) (8.5.0)
# Collecting diskcache (from pyautogen[retrievechat])
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting docker (from pyautogen[retrievechat])
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting flaml (from pyautogen[retrievechat])
#   Downloading FLAML-2.2.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: openai>=1.3 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from pyautogen[retrievechat]) (1.40.6)
# Requirement already satisfied: packaging in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from pyautogen[retrievechat]) (24.1)
# Requirement already satisfied: python-dotenv in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from pyautogen[retrievechat]) (1.0.1)
# Collecting termcolor (from pyautogen[retrievechat])
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: tiktoken in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from pyautogen[retrievechat]) (0.7.0)
# Requirement already satisfied: beautifulsoup4 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from pyautogen[retrievechat]) (4.12.3)
# Collecting chromadb (from pyautogen[retrievechat])
#   Downloading chromadb-0.5.5-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: ipython in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from pyautogen[retrievechat]) (8.26.0)
# Collecting markdownify (from pyautogen[retrievechat])
#   Downloading markdownify-0.13.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting protobuf==4.25.3 (from pyautogen[retrievechat])
#   Using cached protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting pypdf (from pyautogen[retrievechat])
#   Downloading pypdf-4.3.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting sentence-transformers (from pyautogen[retrievechat])
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from langchain-core<0.3.0,>=0.2.32->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from langchain-core<0.3.0,>=0.2.32->langchain) (4.12.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from openai>=1.3->pyautogen[retrievechat]) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from openai>=1.3->pyautogen[retrievechat]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from openai>=1.3->pyautogen[retrievechat]) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from openai>=1.3->pyautogen[retrievechat]) (0.5.0)
# Requirement already satisfied: sniffio in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from openai>=1.3->pyautogen[retrievechat]) (1.3.1)
# Requirement already satisfied: tqdm>4 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from openai>=1.3->pyautogen[retrievechat]) (4.66.5)
# Requirement already satisfied: annotated-types>=0.4.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: soupsieve>1.2 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from beautifulsoup4->pyautogen[retrievechat]) (2.5)
# Collecting build>=1.0.3 (from chromadb->pyautogen[retrievechat])
#   Downloading build-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting chroma-hnswlib==0.7.6 (from chromadb->pyautogen[retrievechat])
#   Downloading chroma_hnswlib-0.7.6-cp310-cp310-win_amd64.whl.metadata (262 bytes)
# Collecting fastapi>=0.95.2 (from chromadb->pyautogen[retrievechat])
#   Downloading fastapi-0.112.1-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb->pyautogen[retrievechat])
#   Downloading uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting posthog>=2.4.0 (from chromadb->pyautogen[retrievechat])
#   Downloading posthog-3.5.2-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb->pyautogen[retrievechat])
#   Downloading onnxruntime-1.19.0-cp310-cp310-win_amd64.whl.metadata (4.5 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb->pyautogen[retrievechat])
#   Downloading opentelemetry_api-1.26.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb->pyautogen[retrievechat])
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb->pyautogen[retrievechat])
#   Downloading opentelemetry_instrumentation_fastapi-0.47b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb->pyautogen[retrievechat])
#   Downloading opentelemetry_sdk-1.26.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting tokenizers>=0.13.2 (from chromadb->pyautogen[retrievechat])
#   Downloading tokenizers-0.20.0-cp310-none-win_amd64.whl.metadata (6.9 kB)
# Collecting pypika>=0.48.9 (from chromadb->pyautogen[retrievechat])
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ---------------------------------------- 0.0/67.3 kB ? eta -:--:--
#      ----------------------- -------------- 41.0/67.3 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 67.3/67.3 kB 731.0 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting overrides>=7.3.1 (from chromadb->pyautogen[retrievechat])
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb->pyautogen[retrievechat])
#   Downloading importlib_resources-6.4.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting grpcio>=1.58.0 (from chromadb->pyautogen[retrievechat])
#   Using cached grpcio-1.65.5-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Collecting bcrypt>=4.0.1 (from chromadb->pyautogen[retrievechat])
#   Downloading bcrypt-4.2.0-cp39-abi3-win_amd64.whl.metadata (9.9 kB)
# Collecting typer>=0.9.0 (from chromadb->pyautogen[retrievechat])
#   Downloading typer-0.12.4-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb->pyautogen[retrievechat])
#   Downloading kubernetes-30.1.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting mmh3>=4.0.1 (from chromadb->pyautogen[retrievechat])
#   Downloading mmh3-4.1.0-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: pywin32>=304 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from docker->pyautogen[retrievechat]) (306)
# Requirement already satisfied: decorator in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from ipython->pyautogen[retrievechat]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from ipython->pyautogen[retrievechat]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from ipython->pyautogen[retrievechat]) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from ipython->pyautogen[retrievechat]) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from ipython->pyautogen[retrievechat]) (2.18.0)
# Requirement already satisfied: stack-data in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from ipython->pyautogen[retrievechat]) (0.6.2)
# Requirement already satisfied: traitlets>=5.13.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from ipython->pyautogen[retrievechat]) (5.14.3)
# Requirement already satisfied: exceptiongroup in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from ipython->pyautogen[retrievechat]) (1.2.2)
# Requirement already satisfied: colorama in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from ipython->pyautogen[retrievechat]) (0.4.6)
# Requirement already satisfied: six<2,>=1.15 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from markdownify->pyautogen[retrievechat]) (1.16.0)
# Collecting transformers<5.0.0,>=4.34.0 (from sentence-transformers->pyautogen[retrievechat])
#   Downloading transformers-4.44.1-py3-none-any.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.7 kB ? eta -:--:--
#      ------------------------------------- -- 41.0/43.7 kB 2.0 MB/s eta 0:00:01
#      ---------------------------------------- 43.7/43.7 kB 2.2 MB/s eta 0:00:00
# Collecting torch>=1.11.0 (from sentence-transformers->pyautogen[retrievechat])
#   Using cached torch-2.4.0-cp310-cp310-win_amd64.whl.metadata (27 kB)
# Collecting scikit-learn (from sentence-transformers->pyautogen[retrievechat])
#   Using cached scikit_learn-1.5.1-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Collecting scipy (from sentence-transformers->pyautogen[retrievechat])
#   Downloading scipy-1.14.1-cp310-cp310-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.8 kB 991.0 kB/s eta 0:00:01
#      ---------------------------------------- 60.8/60.8 kB 1.1 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.15.1 (from sentence-transformers->pyautogen[retrievechat])
#   Downloading huggingface_hub-0.24.6-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: Pillow in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from sentence-transformers->pyautogen[retrievechat]) (10.4.0)
# Requirement already satisfied: regex>=2022.1.18 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from tiktoken->pyautogen[retrievechat]) (2024.7.24)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb->pyautogen[retrievechat])
#   Downloading pyproject_hooks-1.1.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting tomli>=1.1.0 (from build>=1.0.3->chromadb->pyautogen[retrievechat])
#   Using cached tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi>=0.95.2->chromadb->pyautogen[retrievechat])
#   Downloading starlette-0.38.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: httpcore==1.* in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.3->pyautogen[retrievechat]) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.3->pyautogen[retrievechat]) (0.14.0)
# Collecting filelock (from huggingface-hub>=0.15.1->sentence-transformers->pyautogen[retrievechat])
#   Using cached filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.15.1->sentence-transformers->pyautogen[retrievechat])
#   Using cached fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from jedi>=0.16->ipython->pyautogen[retrievechat]) (0.8.4)
# Requirement already satisfied: jsonpointer>=1.9 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.32->langchain) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from kubernetes>=28.1.0->chromadb->pyautogen[retrievechat]) (2.9.0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb->pyautogen[retrievechat])
#   Using cached google_auth-2.34.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb->pyautogen[retrievechat])
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb->pyautogen[retrievechat])
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb->pyautogen[retrievechat])
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb->pyautogen[retrievechat])
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb->pyautogen[retrievechat])
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb->pyautogen[retrievechat])
#   Using cached sympy-1.13.2-py3-none-any.whl.metadata (12 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb->pyautogen[retrievechat])
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata<=8.0.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb->pyautogen[retrievechat])
#   Using cached importlib_metadata-8.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->pyautogen[retrievechat])
#   Downloading googleapis_common_protos-1.63.2-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.26.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->pyautogen[retrievechat])
#   Downloading opentelemetry_exporter_otlp_proto_common-1.26.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.26.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->pyautogen[retrievechat])
#   Downloading opentelemetry_proto-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-asgi==0.47b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->pyautogen[retrievechat])
#   Downloading opentelemetry_instrumentation_asgi-0.47b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.47b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->pyautogen[retrievechat])
#   Downloading opentelemetry_instrumentation-0.47b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.47b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->pyautogen[retrievechat])
#   Downloading opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-util-http==0.47b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->pyautogen[retrievechat])
#   Downloading opentelemetry_util_http-0.47b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: setuptools>=16.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from opentelemetry-instrumentation==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->pyautogen[retrievechat]) (72.1.0)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->pyautogen[retrievechat])
#   Using cached wrapt-1.16.0-cp310-cp310-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: asgiref~=3.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from opentelemetry-instrumentation-asgi==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->pyautogen[retrievechat]) (3.8.1)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb->pyautogen[retrievechat])
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb->pyautogen[retrievechat])
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: wcwidth in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->pyautogen[retrievechat]) (0.2.13)
# Collecting networkx (from torch>=1.11.0->sentence-transformers->pyautogen[retrievechat])
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting jinja2 (from torch>=1.11.0->sentence-transformers->pyautogen[retrievechat])
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.34.0->sentence-transformers->pyautogen[retrievechat])
#   Downloading safetensors-0.4.4-cp310-none-win_amd64.whl.metadata (3.9 kB)
# Collecting tokenizers>=0.13.2 (from chromadb->pyautogen[retrievechat])
#   Downloading tokenizers-0.19.1-cp310-none-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: click>=8.0.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from typer>=0.9.0->chromadb->pyautogen[retrievechat]) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb->pyautogen[retrievechat])
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer>=0.9.0->chromadb->pyautogen[retrievechat])
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb->pyautogen[retrievechat])
#   Downloading httptools-0.6.1-cp310-cp310-win_amd64.whl.metadata (3.7 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb->pyautogen[retrievechat])
#   Downloading watchfiles-0.23.0-cp310-none-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb->pyautogen[retrievechat])
#   Downloading websockets-13.0-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence-transformers->pyautogen[retrievechat])
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers->pyautogen[retrievechat])
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: executing>=1.2.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from stack-data->ipython->pyautogen[retrievechat]) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from stack-data->ipython->pyautogen[retrievechat]) (2.4.1)
# Requirement already satisfied: pure-eval in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from stack-data->ipython->pyautogen[retrievechat]) (0.2.3)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->pyautogen[retrievechat])
#   Using cached cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->pyautogen[retrievechat])
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->pyautogen[retrievechat])
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: zipp>=0.5 in e:\user\miniconda3\envs\ai_prj_final\lib\site-packages (from importlib-metadata<=8.0.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->pyautogen[retrievechat]) (3.19.2)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer>=0.9.0->chromadb->pyautogen[retrievechat])
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb->pyautogen[retrievechat])
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.11.0->sentence-transformers->pyautogen[retrievechat])
#   Using cached MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime>=1.14.1->chromadb->pyautogen[retrievechat])
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb->pyautogen[retrievechat])
#   Using cached pyreadline3-3.4.1-py3-none-any.whl.metadata (2.0 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb->pyautogen[retrievechat])
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->pyautogen[retrievechat])
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Using cached protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
# Using cached pypdf2-3.0.1-py3-none-any.whl (232 kB)
# Downloading faiss_cpu-1.8.0.post1-cp310-cp310-win_amd64.whl (14.6 MB)
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.6 MB 1.9 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/14.6 MB 1.5 MB/s eta 0:00:10
#    ---------------------------------------- 0.1/14.6 MB 1.4 MB/s eta 0:00:11
#     --------------------------------------- 0.2/14.6 MB 1.4 MB/s eta 0:00:11
#     --------------------------------------- 0.3/14.6 MB 1.3 MB/s eta 0:00:12
#     --------------------------------------- 0.3/14.6 MB 1.4 MB/s eta 0:00:11
#    - -------------------------------------- 0.4/14.6 MB 1.3 MB/s eta 0:00:12
MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  43.7/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  43.9/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  43.9/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.1/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.2/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.2/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.4/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.6/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.6/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.7/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.7/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 44.8/44.8 MB 1.2 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Using cached google_auth-2.34.0-py2.py3-none-any.whl (200 kB)
# Downloading googleapis_common_protos-1.63.2-py2.py3-none-any.whl (220 kB)
#    ---------------------------------------- 0.0/220.0 kB ? eta -:--:--
#    ------- ------------------------------- 41.0/220.0 kB 960.0 kB/s eta 0:00:01
#    ------------------ --------------------- 102.4/220.0 kB 1.2 MB/s eta 0:00:01
#    ------------------------------- -------- 174.1/220.0 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 220.0/220.0 kB 1.2 MB/s eta 0:00:00
# Downloading httptools-0.6.1-cp310-cp310-win_amd64.whl (58 kB)
#    ---------------------------------------- 0.0/58.2 kB ? eta -:--:--
#    ---------------------------- ----------- 41.0/58.2 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 58.2/58.2 kB 1.0 MB/s eta 0:00:00
# Using cached importlib_metadata-8.0.0-py3-none-any.whl (24 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Downloading safetensors-0.4.4-cp310-none-win_amd64.whl (285 kB)
#    ---------------------------------------- 0.0/285.9 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/285.9 kB 991.0 kB/s eta 0:00:01
#    --------------- ------------------------ 112.6/285.9 kB 1.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 163.8/285.9 kB 1.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 204.8/285.9 kB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 276.5/285.9 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 285.9/285.9 kB 1.2 MB/s eta 0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading starlette-0.38.2-py3-none-any.whl (72 kB)
#    ---------------------------------------- 0.0/72.0 kB ? eta -:--:--
#    ----------------- ---------------------- 30.7/72.0 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 72.0/72.0 kB 1.3 MB/s eta 0:00:00
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# Downloading watchfiles-0.23.0-cp310-none-win_amd64.whl (275 kB)
#    ---------------------------------------- 0.0/275.9 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/275.9 kB 1.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 112.6/275.9 kB 1.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 153.6/275.9 kB 1.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 204.8/275.9 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 275.9/275.9 kB 1.2 MB/s eta 0:00:00
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Downloading websockets-13.0-cp310-cp310-win_amd64.whl (152 kB)
#    ---------------------------------------- 0.0/152.2 kB ? eta -:--:--
#    ---------- ---------------------------- 41.0/152.2 kB 991.0 kB/s eta 0:00:01
#    ------------------------ --------------- 92.2/152.2 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 152.2/152.2 kB 1.1 MB/s eta 0:00:00
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached filelock-3.15.4-py3-none-any.whl (16 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Downloading pyproject_hooks-1.1.0-py3-none-any.whl (9.2 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached sympy-1.13.2-py3-none-any.whl (6.2 MB)
# Using cached cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl (17 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached wrapt-1.16.0-cp310-cp310-win_amd64.whl (37 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
# Using cached pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53836 sha256=5722c916f8fc9accc0d624e93c94445de0a4eba4e9c04d9e7db698ff13a4957f
#   Stored in directory: c:\users\pc\appdata\local\pip\cache\wheels\e1\26\51\d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pyreadline3, pypika, mpmath, monotonic, mmh3, flatbuffers, wrapt, websockets, websocket-client, tomli, threadpoolctl, termcolor, sympy, shellingham, scipy, safetensors, pyproject_hooks, PyPDF2, pypdf, pyasn1, protobuf, overrides, opentelemetry-util-http, oauthlib, networkx, mdurl, MarkupSafe, joblib, importlib-resources, importlib-metadata, humanfriendly, httptools, grpcio, fsspec, flaml, filelock, faiss-cpu, diskcache, chroma-hnswlib, cachetools, bcrypt, backoff, watchfiles, uvicorn, starlette, scikit-learn, rsa, requests-oauthlib, pyasn1-modules, posthog, opentelemetry-proto, markdownify, markdown-it-py, jinja2, huggingface-hub, googleapis-common-protos, docker, deprecated, coloredlogs, build, torch, tokenizers, rich, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, google-auth, fastapi, typer, transformers, pyautogen, opentelemetry-semantic-conventions, opentelemetry-instrumentation, kubernetes, sentence-transformers, opentelemetry-sdk, opentelemetry-instrumentation-asgi, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, chromadb
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.2.0
#     Uninstalling importlib_metadata-8.2.0:
#       Successfully uninstalled importlib_metadata-8.2.0
# Successfully installed MarkupSafe-2.1.5 PyPDF2-3.0.1 backoff-2.2.1 bcrypt-4.2.0 build-1.2.1 cachetools-5.5.0 chroma-hnswlib-0.7.6 chromadb-0.5.5 coloredlogs-15.0.1 deprecated-1.2.14 diskcache-5.6.3 docker-7.1.0 faiss-cpu-1.8.0.post1 fastapi-0.112.1 filelock-3.15.4 flaml-2.2.0 flatbuffers-24.3.25 fsspec-2024.6.1 google-auth-2.34.0 googleapis-common-protos-1.63.2 grpcio-1.65.5 httptools-0.6.1 huggingface-hub-0.24.6 humanfriendly-10.0 importlib-metadata-8.0.0 importlib-resources-6.4.4 jinja2-3.1.4 joblib-1.4.2 kubernetes-30.1.0 markdown-it-py-3.0.0 markdownify-0.13.1 mdurl-0.1.2 mmh3-4.1.0 monotonic-1.6 mpmath-1.3.0 networkx-3.3 oauthlib-3.2.2 onnxruntime-1.19.0 opentelemetry-api-1.26.0 opentelemetry-exporter-otlp-proto-common-1.26.0 opentelemetry-exporter-otlp-proto-grpc-1.26.0 opentelemetry-instrumentation-0.47b0 opentelemetry-instrumentation-asgi-0.47b0 opentelemetry-instrumentation-fastapi-0.47b0 opentelemetry-proto-1.26.0 opentelemetry-sdk-1.26.0 opentelemetry-semantic-conventions-0.47b0 opentelemetry-util-http-0.47b0 overrides-7.7.0 posthog-3.5.2 protobuf-4.25.3 pyasn1-0.6.0 pyasn1-modules-0.4.0 pyautogen-0.2.35 pypdf-4.3.1 pypika-0.48.9 pyproject_hooks-1.1.0 pyreadline3-3.4.1 requests-oauthlib-2.0.0 rich-13.7.1 rsa-4.9 safetensors-0.4.4 scikit-learn-1.5.1 scipy-1.14.1 sentence-transformers-3.0.1 shellingham-1.5.4 starlette-0.38.2 sympy-1.13.2 termcolor-2.4.0 threadpoolctl-3.5.0 tokenizers-0.19.1 tomli-2.0.1 torch-2.4.0 transformers-4.44.1 typer-0.12.4 uvicorn-0.30.6 watchfiles-0.23.0 websocket-client-1.8.0 websockets-13.0 wrapt-1.16.0

# %%
import autogen
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.llms import OpenAI
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
from PyPDF2 import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
config_list = [
    {
        "model": "gpt-4-1106-preview",
        "api_key": "openai_api",
    }
]

llm_config_proxy = {
    "seed": 42,  # change the seed for different trials
    "temperature": 0,
    "config_list": config_list,
    "request_timeout": 600
}

# %%
reader = PdfReader('/content/openchat.pdf')
corpus = ''.join([p.extract_text() for p in reader.pages if p.extract_text()])

splitter =  RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200,)
chunks = splitter.split_text(corpus)

embeddings = OpenAIEmbeddings(openai_api_key = openai_api)
vectors = FAISS.from_texts(chunks, embeddings)

# %%
qa = ConversationalRetrievalChain.from_llm(
    OpenAI(temperature=0),
    vectors.as_retriever(),
    memory=ConversationBufferMemory(memory_key="chat_history", 
    return_messages=True),
)

# %%
llm_config_assistant = {
    "Seed" : 42,
    "temperature": 0,
        "functions": [
        {
            "name": "answer_PDF_question",
            "description": "Answer any PDF related questions",
            "parameters": {
                "type": "object",
                "properties": {
                    "question": {
                        "type": "string",
                        "description": "The question to ask in relation to PDF",
                    }
                },
                "required": ["question"],
            },
            
        }
    ],
    "config_list": config_list,
    "timeout": 120,
}

# %%
assistant = autogen.AssistantAgent(
            name="assistant",
            llm_config=llm_config_assistant,
            system_message="""You are a helpful assistant, Answer the question based on the context. 
                              Keep the answer accurate. Respond "Unsure about answer" if not sure about the answer."""
            
        )

# %%
def answer_PDF_question(question):
    # Sử dụng qa để trả lời câu hỏi
    response = qa({"question": question})
    return response['answer']

# %%
user_proxy = autogen.UserProxyAgent(  
            name="user_proxy",
            human_input_mode="NEVER", 
            max_consecutive_auto_reply=10,
            code_execution_config={"work_dir": "coding"},
            # llm_config_assistant = llm_config_assistant,
            # function_map={
            #     "answer_PDF_question": llm_config_assistant["functions"][0]["name"]
            # }
            function_map={
                "answer_PDF_question": answer_PDF_question
            }
        )

# %%
user_proxy.initiate_chat(
    assistant,
    message="""
Write a Openchat word blog post titled why openchat better than GPT3 that uses the exact keyword OpenChat 
at least once every 100 words. The blog post should include an introduction, main body,
 and conclusion. The conclusion should invite readers to leave a comment. The main
 body should be split into at least 4 different subsections.
"""
)

# %% [markdown]
# user_proxy (to assistant):
#
#
# Write a Openchat word blog post titled why openchat better than GPT3 that uses the exact keyword OpenChat
# at least once every 100 words. The blog post should include an introduction, main body,
#  and conclusion. The conclusion should invite readers to leave a comment. The main
#  body should be split into at least 4 different subsections.
#
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# # Why OpenChat is Better Than GPT-3
#
# ## Introduction
#
# In the ever-evolving landscape of artificial intelligence, OpenChat has emerged as a groundbreaking platform, offering a unique set of capabilities that set it apart from its predecessors like GPT-3. In this blog post, we will delve into the reasons why OpenChat is not just a step ahead but a leap forward in AI communication technology.
#
# ## Main Body
#
# ### Enhanced Contextual Understanding
#
# OpenChat's ability to understand context surpasses that of GPT-3. It can maintain the thread of a conversation over a longer period, which allows for more coherent and meaningful interactions. This is particularly beneficial in customer service applications where conversations can be complex and require a deep understanding of the issue at hand.
#
# ### Superior Customization
#
# One of the key advantages of OpenChat is its superior customization options. Unlike GPT-3, OpenChat can be tailored to fit the specific needs of any business or application. This means that it can adhere to brand voice, manage specialized knowledge bases, and integrate seamlessly with existing systems, providing a more personalized experience for users.
#
# ### Advanced Learning Capabilities
#
# OpenChat is designed to learn and adapt more efficiently than GPT-3. It can quickly incorporate new information and adjust its responses accordingly. This continuous learning process ensures that OpenChat remains up-to-date with the latest data, trends, and user preferences, making it an invaluable tool for dynamic and fast-paced environments.
#
# ### Open-Source Community
#
# The open-source nature of OpenChat is a game-changer. It allows developers from around the world to contribute to its development, leading to rapid innovation and improvement. This collaborative approach ensures that OpenChat is constantly evolving and benefiting from the collective expertise of a global community, unlike the more closed ecosystem of GPT-3.
#
# ## Conclusion
#
# OpenChat represents a significant advancement in AI-powered communication, offering enhanced contextual understanding, superior customization, advanced learning capabilities, and the support of an open-source community. Its ability to provide more nuanced and adaptable interactions makes it a superior choice for businesses and developers looking to harness the power of AI.
#
# We invite you to share your thoughts and experiences with OpenChat and GPT-3. Have you noticed the differences in your interactions? Leave a comment below and join the conversation about the future of AI communication.

# %% [markdown]
# multi_agent_tomulti_model

# %%
llm_config_text = {
    "seed": 42,
    "temperature": 0,
    "functions": [
        {
            "name": "generate_text",
            "description": "Generate detailed text based on a given description",
            "parameters": {
                "type": "object",
                "properties": {
                    "description": {
                        "type": "string",
                        "description": "The description for which to generate text",
                    }
                },
                "required": ["description"],
            },
        }
    ],
    "config_list": config_list,
    "timeout": 120,
}

text_agent = autogen.AssistantAgent(
    name="text_generator",
    llm_config=llm_config_text,
    system_message="""You are a text generation assistant. Generate detailed text based on the given description. Ensure the text is coherent and relevant."""
)

# %%
llm_config_code = {
    "seed": 42,
    "temperature": 0,
    "functions": [
        {
            "name": "generate_code",
            "description": "Generate code snippets based on a given description",
            "parameters": {
                "type": "object",
                "properties": {
                    "description": {
                        "type": "string",
                        "description": "The description for which to generate code",
                    }
                },
                "required": ["description"],
            },
        }
    ],
    "config_list": config_list,
    "timeout": 120,
}

code_agent = autogen.AssistantAgent(
    name="code_generator",
    llm_config=llm_config_code,
    system_message="""You are a code generation assistant. Generate code snippets based on the given description. Ensure the code is correct and relevant."""
)

# %%
llm_config_image = {
    "seed": 42,
    "temperature": 0,
    "functions": [
        {
            "name": "generate_image",
            "description": "Generate an image based on a given description",
            "parameters": {
                "type": "object",
                "properties": {
                    "description": {
                        "type": "string",
                        "description": "The description for which to generate an image",
                    }
                },
                "required": ["description"],
            },
        }
    ],
    "config_list": config_list,
    "timeout": 120,
}

image_agent = autogen.AssistantAgent(
    name="image_generator",
    llm_config=llm_config_image,
    system_message="""You are an image generation assistant. Generate an image based on the given description. Ensure the image is relevant and accurate."""
)

# %%
def initiate_conversation_with_agents(description):
    # Khởi tạo các cuộc trò chuyện với từng agent
    response_text = user_proxy.initiate_chat(
        text_agent,
        message=f"Generate a detailed text based on: {description}"
    )
    
    response_code = user_proxy.initiate_chat(
        code_agent,
        message=f"Generate a code snippet based on: {description}"
    )
    
    response_image = user_proxy.initiate_chat(
        image_agent,
        message=f"Generate an image based on: {description}"
    )

    return response_text, response_code, response_image

# Ví dụ sử dụng
description = "an innovative AI solution"
text, code, image = initiate_conversation_with_agents(description)

print("Text Response:", text)
print("Code Response:", code)
print("Image Response:", image)
